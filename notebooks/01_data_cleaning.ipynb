# %%
import pandas as pd

df = pd.read_csv("../data/raw/immigrant_data.csv")
df.head(10)
# Out:
#    person_id country_of_origin    entry_type  previous_profession  \
# 0          1            Mexico  undocumented               farmer
# 1          2       Philippines  undocumented               farmer
# 2          3             China  student_visa           accountant
# 3          4             China     work_visa               driver
# 4          5             India  tourist_visa                nurse
# 5          6          Colombia  undocumented               farmer
# 6          7             China  undocumented           accountant
# 7          8       Philippines      marriage             engineer
# 8          9            Mexico     work_visa           accountant
# 9         10            Brazil      marriage  construction_worker
#
#   current_profession  years_in_us english_level education_level  \
# 0                 IT            6      advanced     high_school
# 1                 IT            3      advanced     high_school
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   person_id            300 non-null    int64
#  1   country_of_origin    300 non-null    object
#  2   entry_type           300 non-null    object
#  3   previous_profession  300 non-null    object
#  4   current_profession   300 non-null    object
#  5   years_in_us          300 non-null    int64
#  6   english_level        300 non-null    object
#  7   education_level      300 non-null    object
#  8   hours_per_week       300 non-null    int64
#  9   annual_income        300 non-null    int64
#  10  stress_level         300 non-null    int64
#  11  job_satisfaction     300 non-null    int64
#  12  employment_type      300 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 30.6+ KB

# %%
df.shape
# Out:
# (300, 13)

# %%
df.columns
# Out:
# Index(['person_id', 'country_of_origin', 'entry_type', 'previous_profession',
#        'current_profession', 'years_in_us', 'english_level', 'education_level',
#        'hours_per_week', 'annual_income', 'stress_level', 'job_satisfaction',
#        'employment_type'],
#       dtype='object')

# %%
# DADOS FALTANTES
df.isnull().sum()
# Out:
# person_id              0
# country_of_origin      0
# entry_type             0
# previous_profession    0
# current_profession     0
# years_in_us            0
# english_level          0
# education_level        0
# hours_per_week         0
# annual_income          0
# stress_level           0
# job_satisfaction       0
# employment_type        0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# person_id              0.0
# country_of_origin      0.0
# entry_type             0.0
# previous_profession    0.0
# current_profession     0.0
# years_in_us            0.0
# english_level          0.0
# education_level        0.0
# hours_per_week         0.0
# annual_income          0.0
# stress_level           0.0
# job_satisfaction       0.0
# employment_type        0.0
# dtype: float64

# %%
df.describe()
# Out:
#         person_id  years_in_us  hours_per_week  annual_income  stress_level  \
# count  300.000000   300.000000      300.000000     300.000000    300.000000
# mean   150.500000     6.403333       49.553333   54282.436667      7.130000
# std     86.746758     3.410684        8.067057   25321.625208      1.961102
# min      1.000000     1.000000       38.000000   25104.000000      4.000000
# 25%     75.750000     4.000000       43.000000   35810.500000      5.000000
# 50%    150.500000     6.000000       48.000000   45466.000000      7.000000
# 75%    225.250000     9.000000       56.000000   70952.000000      9.000000
# max    300.000000    12.000000       70.000000  128863.000000     10.000000
#
#        job_satisfaction
# count        300.000000
# mean           6.060000
# std            1.937933
# min            3.000000
# 25%            4.000000
# 50%            6.000000
# 75%            8.000000
# max            9.000000

# %%
df.describe(include="all")
# Out:
#          person_id country_of_origin entry_type previous_profession  \
# count   300.000000               300        300                 300
# unique         NaN                 6          5                   8
# top            NaN             China  work_visa              farmer
# freq           NaN                62         68                  45
# mean    150.500000               NaN        NaN                 NaN
# std      86.746758               NaN        NaN                 NaN
# min       1.000000               NaN        NaN                 NaN
# 25%      75.750000               NaN        NaN                 NaN
# 50%     150.500000               NaN        NaN                 NaN
# 75%     225.250000               NaN        NaN                 NaN
# max     300.000000               NaN        NaN                 NaN
#
#        current_profession  years_in_us english_level education_level  \
# count                 300   300.000000           300             300
# ...

# %%
df["country_of_origin"].value_counts()
# Out:
# country_of_origin
# China          62
# Brazil         51
# Colombia       50
# India          49
# Mexico         48
# Philippines    40
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['person_id',
#  'country_of_origin',
#  'entry_type',
#  'previous_profession',
#  'current_profession',
#  'years_in_us',
#  'english_level',
#  'education_level',
#  'hours_per_week',
#  'annual_income',
#  'stress_level',
#  'job_satisfaction',
#  'employment_type']

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
)

# %%
df.columns
# Out:
# Index(['person_id', 'country_of_origin', 'entry_type', 'previous_profession',
#        'current_profession', 'years_in_us', 'english_level', 'education_level',
#        'hours_per_week', 'annual_income', 'stress_level', 'job_satisfaction',
#        'employment_type'],
#       dtype='object')

# %%
df.to_csv("../data/processed/immigrant_data_cleaned.csv", index=False)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["income_per_hour"] = df["annual_income"] / (df["hours_per_week"] * 52)

# %%
df.to_csv("../data/processed/immigrant_data_cleaned.csv", index=False)

# %%
df.columns.to_list()
# Out:
# ['person_id',
#  'country_of_origin',
#  'entry_type',
#  'previous_profession',
#  'current_profession',
#  'years_in_us',
#  'english_level',
#  'education_level',
#  'hours_per_week',
#  'annual_income',
#  'stress_level',
#  'job_satisfaction',
#  'employment_type',
#  'income_per_hour']
