# %%
# Insight 1:
# Pessoas com inglês avançado têm renda significativamente maior

# Insight 2:
# Muitos profissionais qualificados trabalham em áreas diferentes

# Insight 3:
# Mais horas não significam necessariamente mais satisfação

# Insight 4:
# Tipo de entrada influencia renda
